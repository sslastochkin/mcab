# %% [markdown]
# # First Steps

# %%
from mcab import *

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# Lets get started!

# %%
rand = RandomData(42).normal_data(size=10_000)
sns.histplot(rand)
# Out:
# <Axes: ylabel='Count'>
